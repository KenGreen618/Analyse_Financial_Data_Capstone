# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt

# %%
df = yf.download(['XLY', 'XLI', 'XLE', 'XLK', 'XLF', 'XLV', 'XLU', 'XLB'], start="2000-01-01", end="2022-03-07")
# Out:
# [*********************100%***********************]  8 of 8 completed

# %%
df
# Out:
#             Adj Close                                                \
#                   XLB        XLE        XLF         XLI         XLK
# Date
# 2000-01-03  15.753363  15.463380  11.943723   19.309528   42.623905
# 2000-01-04  15.601705  15.172296  11.421593   18.776064   40.461483
# 2000-01-05  16.246246  15.572523  11.331853   18.692383   39.860779
# 2000-01-06  16.663301  16.172861  11.829509   18.943426   38.539318
# 2000-01-07  16.653835  16.345699  12.025304   19.665180   39.212086
# ...               ...        ...        ...         ...         ...
# 2022-02-28  83.379997  70.580002  38.520000   99.889999  154.070007
# 2022-03-01  81.459999  71.290001  37.099998   98.400002  150.990005
# 2022-03-02  83.250000  72.919998  38.060001  100.500000  154.259995
# 2022-03-03  83.349998  73.120003  37.939999  100.610001  152.419998
# 2022-03-04  83.059998  75.230003  37.230000  100.389999  149.750000
#
#                                                    Close             ...  \
#                   XLU         XLV         XLY        XLB        XLE  ...
# Date                                                                 ...
# 2000-01-03  12.540847   21.906908   23.124073  25.968750  26.562500  ...
# 2000-01-04  12.162552   21.409796   22.428431  25.718750  26.062500  ...
# 2000-01-05  12.469466   21.217730   22.152569  26.781250  26.750000  ...
# 2000-01-06  12.448056   21.285522   22.404449  27.468750  27.781250  ...
# 2000-01-07  12.555130   21.545362   23.459904  27.453125  28.078125  ...
# ...               ...         ...         ...        ...        ...  ...
# 2022-02-28  67.930000  129.960007  177.429993  83.379997  70.580002  ...
# 2022-03-01  67.339996  129.240005  174.740005  81.459999  71.290001  ...
# 2022-03-02  68.160004  131.190002  178.410004  83.250000  72.919998  ...
# 2022-03-03  69.360001  131.860001  174.369995  83.349998  73.120003  ...
# 2022-03-04  70.889999  132.520004  171.600006  83.059998  75.230003  ...
#
#                   Open                Volume                                 \
#                    XLV         XLY       XLB       XLE        XLF       XLI
# Date
# 2000-01-03   31.000000   31.000000    140500    380300    1185699     82800
# 2000-01-04   30.187500   29.687500    258000    722200     885705    146900
# 2000-01-05   29.781250   29.343750    102700    337800     717181    129200
# 2000-01-06   29.312500   29.046875   1335000    133100     415832     54000
# 2000-01-07   29.468750   29.500000    620100    468000     468149     32900
# ...                ...         ...       ...       ...        ...       ...
# 2022-02-28  128.850006  174.460007  11229000  48190000  107353300  18309100
# 2022-03-01  129.279999  177.169998  13131900  62115500  129873100  21884800
# 2022-03-02  129.809998  175.369995   9571400  45454100   88182500  16881400
# 2022-03-03  131.770004  179.320007   9735800  44559900   71952600  14831600
# 2022-03-04  130.529999  173.380005   8664500  52608400  105904100  17167400
#
#
#                  XLK       XLU       XLV       XLY
# Date
# 2000-01-03    938100    176700    246700    212900
# 2000-01-04    545500     93500     35300    177200
# 2000-01-05   1906000    273400    137600    124600
# 2000-01-06   1670000     34500     50000    135800
# 2000-01-07    686000     46200     22100     70000
# ...              ...       ...       ...       ...
# 2022-02-28  17408600  18350600  17987400  16156700
# 2022-03-01  14962500  16732300  14064200  13498800
# 2022-03-02  12796200  14629900  12395600  10131400
# 2022-03-03  11725300  20735600  11172600  11202000
# 2022-03-04  13365600  24341800  12160400  10829600
#
# [5579 rows x 48 columns]

# %%
adj_close_df = df['Adj Close']
print(adj_close_df)

adj_close_df.plot()
plt.ylabel("Adjusted Closing Price Over Time")
plt.xlabel("Date")
plt.title("Sector ETF's Adjusted Price")
plt.show()
# Out:
#                   XLB        XLE        XLF         XLI         XLK  \
# Date
# 2000-01-03  15.753363  15.463380  11.943723   19.309528   42.623905
# 2000-01-04  15.601705  15.172296  11.421593   18.776064   40.461483
# 2000-01-05  16.246246  15.572523  11.331853   18.692383   39.860779
# 2000-01-06  16.663301  16.172861  11.829509   18.943426   38.539318
# 2000-01-07  16.653835  16.345699  12.025304   19.665180   39.212086
# ...               ...        ...        ...         ...         ...
# 2022-02-28  83.379997  70.580002  38.520000   99.889999  154.070007
# 2022-03-01  81.459999  71.290001  37.099998   98.400002  150.990005
# 2022-03-02  83.250000  72.919998  38.060001  100.500000  154.259995
# 2022-03-03  83.349998  73.120003  37.939999  100.610001  152.419998
# 2022-03-04  83.059998  75.230003  37.230000  100.389999  149.750000
#
#                   XLU         XLV         XLY
# Date
# 2000-01-03  12.540847   21.906908   23.124073
# 2000-01-04  12.162552   21.409796   22.428431
# 2000-01-05  12.469466   21.217730   22.152569
# 2000-01-06  12.448056   21.285522   22.404449
# 2000-01-07  12.555130   21.545362   23.459904
# ...               ...         ...         ...
# 2022-02-28  67.930000  129.960007  177.429993
# 2022-03-01  67.339996  129.240005  174.740005
# 2022-03-02  68.160004  131.190002  178.410004
# 2022-03-03  69.360001  131.860001  174.369995
# 2022-03-04  70.889999  132.520004  171.600006
#
# [5579 rows x 8 columns]

# %%
etf_returns_df = adj_close_df.pct_change()
etf_returns_df.plot()
plt.ylabel("Returns Over Time")
plt.xlabel("Date")
plt.title("Sector ETF Returns")
plt.figure(figsize=(16,9))
plt.show()

# %%
fig = plt.figure(figsize=(15,15))
ax1 = fig.add_subplot(421)
ax2 = fig.add_subplot(422)
ax3 = fig.add_subplot(423)
ax4 = fig.add_subplot(424)
ax5 = fig.add_subplot(425)
ax6 = fig.add_subplot(426)
ax7 = fig.add_subplot(427)
ax8 = fig.add_subplot(428)

ax1.plot(etf_returns_df['XLY'])
ax1.set_title("XLY - Consumer Discretionary")
ax2.plot(etf_returns_df['XLI'])
ax2.set_title("XLI - Industrial")
ax3.plot(etf_returns_df['XLE'])
ax3.set_title("XLE - Energy")
ax4.plot(etf_returns_df['XLK'])
ax4.set_title("XLK - Technology")
ax5.plot(etf_returns_df['XLF'])
ax5.set_title("XLF - Financial")
ax6.plot(etf_returns_df['XLV'])
ax6.set_title("XLV - Health Care")
ax7.plot(etf_returns_df['XLU'])
ax7.set_title("XLU - Utilities")
ax8.plot(etf_returns_df['XLB'])
ax8.set_title("XLB - Materials")



plt.tight_layout()
plt.show()

# %%
# interesting findings from the isolated daily returns shown above
# Financials had significantly higher volatility than all other sectors during the 08 financial crisis, because 
# as the name of the crisis suggests, the crisis orginated from the financial sector and the most vulnerable area of that 
# deleveraging was the highly leveraged financial institutions
# this is as opposed to the 2020 c19 sell off which saw energy significantly hit hardest as lockdowns halted travel and oil
# infamously dipped to negative 40 USD on WTI futures contracts.

# %%
# calculating daily mean returns
daily_mean_returns = etf_returns_df.mean()
print(daily_mean_returns)
daily_mean_returns = daily_mean_returns.sort_values()
print(daily_mean_returns)
# Out:
# XLB    0.000416
# XLE    0.000456
# XLF    0.000381
# XLI    0.000390
# XLK    0.000358
# XLU    0.000386
# XLV    0.000389
# XLY    0.000459
# dtype: float64
# XLK    0.000358
# XLF    0.000381
# XLU    0.000386
# XLV    0.000389
# XLI    0.000390
# XLB    0.000416
# XLE    0.000456
# XLY    0.000459
# dtype: float64

# %%
# daily mean index for x axis
daily_mean_returns.keys()

# grab each daily mean value for the y axis
height = []
for key in daily_mean_returns.keys():
    height.append(daily_mean_returns[key])

# arrange keys on x acis based on length
x_pos = np.arange(len(daily_mean_returns.keys()))

# plot bar chart
plt.bar(x_pos, height)
plt.xticks(x_pos, daily_mean_returns.keys())
plt.xlabel("Sector ETFs")
plt.ylabel("Daily mean")
plt.title("Daily mean rate of return")

plt.show()

# %%
# daily mean index for x axis
daily_mean_returns.keys()

# grab each daily mean value for the y axis
height = []
for key in daily_mean_returns.keys():
    height.append(daily_mean_returns[key]*252)

# arrange keys on x acis based on length
x_pos = np.arange(len(daily_mean_returns.keys()))

# plot bar chart
plt.bar(x_pos, height)
plt.xticks(x_pos, daily_mean_returns.keys())
plt.xlabel("Sector ETFs")
plt.ylabel("Daily mean")
plt.title("Annualised mean rate of return")

plt.show()

# %%
# calcuate variance 
daily_variance = etf_returns_df.var()
print(daily_variance)
daily_variance = daily_variance.sort_values()
print(daily_variance)

# variance index for the x axis 
daily_variance.keys()

# grab each variance value for the y axis
height = []
for key in daily_variance.keys():
    height.append(daily_variance[key])

# arrange keys on x axis based on length
x_pos = np.arange(len(daily_variance.keys()))

# plot bar chart
plt.bar(x_pos, height)
plt.title('Sector ETFs variance comparison')
plt.xticks(x_pos, daily_variance.keys())
plt.xlabel("Sector ETFs")
plt.ylabel("Daily Variance")
plt.show()
# Out:
# XLB    0.000235
# XLE    0.000342
# XLF    0.000355
# XLI    0.000189
# XLK    0.000265
# XLU    0.000151
# XLV    0.000132
# XLY    0.000198
# dtype: float64
# XLV    0.000132
# XLU    0.000151
# XLI    0.000189
# XLY    0.000198
# XLB    0.000235
# XLK    0.000265
# XLE    0.000342
# XLF    0.000355
# dtype: float64

# %%
# calculate standard deviation
daily_std = etf_returns_df.std()
daily_std = daily_std.sort_values()
print(daily_std)
daily_std.keys()
height = []
for key in daily_std.keys():
    height.append(daily_std[key])
x_pos = np.arange(len(daily_std.keys()))
plt.bar(x_pos, height)
plt.xticks(x_pos, daily_std.keys())
plt.xlabel("Sector ETFs")
plt.ylabel("std")
plt.title("Daily std")
plt.show()
# Out:
# XLV    0.011492
# XLU    0.012306
# XLI    0.013735
# XLY    0.014088
# XLB    0.015330
# XLK    0.016294
# XLE    0.018498
# XLF    0.018829
# dtype: float64

# %%
etf_correlations = etf_returns_df.corr().abs()
print(etf_correlations)
s = etf_correlations.unstack()
so = s.sort_values()
print('sorted lowest correlations')
print(so)

def get_redundant_pairs(input_df):
    #get diagonal and lower triangular pairs of correlation matrix
    pairs_to_drop = set()
    cols = input_df.columns
    for i in range(0, input_df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(input_df, n=8):
    au_corr = input_df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(input_df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print('top 5 highest correlations')
print(get_top_abs_correlations(etf_returns_df, 5))
# Out:
#           XLB       XLE       XLF       XLI       XLK       XLU       XLV  \
# XLB  1.000000  0.705573  0.702769  0.825043  0.621048  0.527133  0.634638
# XLE  0.705573  1.000000  0.598694  0.670820  0.482674  0.506320  0.504756
# XLF  0.702769  0.598694  1.000000  0.788472  0.638010  0.499993  0.625006
# XLI  0.825043  0.670820  0.788472  1.000000  0.744175  0.561076  0.723516
# XLK  0.621048  0.482674  0.638010  0.744175  1.000000  0.466028  0.677176
# XLU  0.527133  0.506320  0.499993  0.561076  0.466028  1.000000  0.535051
# XLV  0.634638  0.504756  0.625006  0.723516  0.677176  0.535051  1.000000
# XLY  0.733159  0.556714  0.756604  0.820417  0.732953  0.503086  0.694120
#
#           XLY
# XLB  0.733159
# XLE  0.556714
# XLF  0.756604
# XLI  0.820417
# XLK  0.732953
# XLU  0.503086
# XLV  0.694120
# XLY  1.000000
# sorted lowest correlations
# XLK  XLU    0.466028
# XLU  XLK    0.466028
# XLK  XLE    0.482674
# XLE  XLK    0.482674
# XLU  XLF    0.499993
#               ...
# XLI  XLI    1.000000
# XLF  XLF    1.000000
# XLE  XLE    1.000000
# XLV  XLV    1.000000
# XLY  XLY    1.000000
# Length: 64, dtype: float64
# top 5 highest correlations
# XLB  XLI    0.825043
# XLI  XLY    0.820417
# XLF  XLI    0.788472
#      XLY    0.756604
# XLI  XLK    0.744175
# dtype: float64

# %%
# mean variance portfolio analysis

# %%
etf_returns_df
# Out:
#                  XLB       XLE       XLF       XLI       XLK       XLU  \
# Date
# 2000-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2000-01-04 -0.009627 -0.018824 -0.043716 -0.027627 -0.050733 -0.030165
# 2000-01-05  0.041312  0.026379 -0.007857 -0.004457 -0.014846  0.025234
# 2000-01-06  0.025671  0.038551  0.043917  0.013430 -0.033152 -0.001717
# 2000-01-07 -0.000568  0.010687  0.016551  0.038101  0.017457  0.008602
# ...              ...       ...       ...       ...       ...       ...
# 2022-02-28 -0.011382  0.024681 -0.014834  0.007667 -0.001814  0.005179
# 2022-03-01 -0.023027  0.010059 -0.036864 -0.014916 -0.019991 -0.008685
# 2022-03-02  0.021974  0.022864  0.025876  0.021341  0.021657  0.012177
# 2022-03-03  0.001201  0.002743 -0.003153  0.001095 -0.011928  0.017606
# 2022-03-04 -0.003479  0.028857 -0.018714 -0.002187 -0.017517  0.022059
#
#                  XLV       XLY
# Date
# 2000-01-03       NaN       NaN
# 2000-01-04 -0.022692 -0.030083
# 2000-01-05 -0.008971 -0.012300
# 2000-01-06  0.003195  0.011370
# 2000-01-07  0.012207  0.047109
# ...              ...       ...
# 2022-02-28 -0.007560  0.007038
# 2022-03-01 -0.005540 -0.015161
# 2022-03-02  0.015088  0.021003
# 2022-03-03  0.005107 -0.022645
# 2022-03-04  0.005005 -0.015886
#
# [5579 rows x 8 columns]

# %%
print(etf_returns_df.mean())
# Out:
# XLB    0.000416
# XLE    0.000456
# XLF    0.000381
# XLI    0.000390
# XLK    0.000358
# XLU    0.000386
# XLV    0.000389
# XLY    0.000459
# dtype: float64

# %%
def portfolio_return(weights):
    return np.dot(etf_returns_df.mean()*252, weights)

# %%
returns.cov()
# Out:
#           XLB       XLE       XLF       XLI       XLK       XLU       XLV  \
# XLB  0.000235  0.000202  0.000204  0.000174  0.000155  0.000100  0.000112
# XLE  0.000202  0.000345  0.000211  0.000172  0.000146  0.000116  0.000108
# XLF  0.000204  0.000211  0.000354  0.000205  0.000196  0.000117  0.000136
# XLI  0.000174  0.000172  0.000205  0.000189  0.000167  0.000095  0.000115
# XLK  0.000155  0.000146  0.000196  0.000167  0.000265  0.000093  0.000127
# XLU  0.000100  0.000116  0.000117  0.000095  0.000093  0.000151  0.000076
# XLV  0.000112  0.000108  0.000136  0.000115  0.000127  0.000076  0.000132
# XLY  0.000159  0.000147  0.000202  0.000160  0.000169  0.000088  0.000113
#
#           XLY
# XLB  0.000159
# XLE  0.000147
# XLF  0.000202
# XLI  0.000160
# XLK  0.000169
# XLU  0.000088
# XLV  0.000113
# XLY  0.000199

# %%
def portfolio_std(weights):
    return np.dot(etf_returns_df.std()*np.sqrt(252), weights)

# %%
def weightscreator(returns):
    rand = np.random.random(len(returns.columns))
    rand /= rand.sum()
    return rand

# %%
returns_ = []
std_dev_ = []
weights_ = []

for i in range(3000):
    weights = weightscreator(returns)
    returns_.append(portfolio_return(weights))
    std_dev_.append(portfolio_std(weights))
    weights_.append(weights)

# %%
xvals = (0.016294, 0.018829, 0.012306, 0.011492, 0.013735, 0.015330, 0.018498, 0.014088)
yvals = (0.000358, 0.000381, 0.000386, 0.000389, 0.000390, 0.000416, 0.000456, 0.000459)

plt.scatter(std_dev_, returns_, alpha = 0.4)
plt.title('Efficient Frontier')
plt.xlabel('Std Deviation')
plt.ylabel('Returns')
plt.show()
